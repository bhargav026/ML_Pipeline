# %% [markdown]
# TRY, EXCEPT, EXCEPTION, ELSE, FINALLY are need to understand and RAISE own exception or errors
#
# *   List item
# *   List item

# %%
a=5
a/10
# Out:
# 0.5

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-deacdc4ccabc> in <module>
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
a/0
print('hi')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-c7e188546e4e> in <module>
# ----> 1 a/0
#       2 print('hi')
#
# ZeroDivisionError: division by zero

# %%
a=5
b=int(input())
a/b
# Out:
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-005fc1f752c4> in <module>
#       1 a=5
#       2 b=int(input())
# ----> 3 a/b
#
# ZeroDivisionError: division by zero

# %%
f=open('test.txt','r')
f.write('bfiuhfidhf jsndvibv jnjisdniu')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-4af51883020d> in <module>
# ----> 1 f=open('test.txt','r')
#       2 f.write('bfiuhfidhf jsndvibv jnjisdniu')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
f=open('test.txt','w')
f.write('bfiuhfidhf jsndvibv jnjisdniu')
# Out:
# 29

# %%
f.close()

# %%
try:
  f=open('test.txt','r')
  f.write('bfiuhfidhf jsndvibv jnjisdniu')
except:
  print('there is a mistake')
print('it is nice')
# Out:
# there is a mistake
# it is nice

# %%
try:
  a=5
  b=int(input())
  a/b
except:
  print('there is an error')
# Out:
# 0
# there is an error

# %%
l=[4,5,6,8,8,1,6,47,94]
try:
  for i range(len(l)):
    print(i)
except:
  print('check code')
# Out:
#   File "<ipython-input-21-7c7dd68ae4e7>", line 3
#     for i range(len(l)):
#               ^
# SyntaxError: invalid syntax

# %%
l=[4,5,6,8,8,1,6,47,94]
try:
  for i in range(len(l)+1):
    print(l[i])
except:
  print('check code')
# Out:
# 4
# 5
# 6
# 8
# 8
# 1
# 6
# 47
# 94
# check code

# %%
for i in range(len(l)+1):
    print(l[i])
# Out:
# 4
# 5
# 6
# 8
# 8
# 1
# 6
# 47
# 94
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-312ea121e293> in <module>
#       1 for i in range(len(l)+1):
# ----> 2     print(l[i])
#
# IndexError: list index out of range

# %%
l=[4,5,6,8,8,1,6,47,94]
try:
  for i in range(len(l)+1):
    print(l[i])
except Exception as e:
  print(e)
# Out:
# 4
# 5
# 6
# 8
# 8
# 1
# 6
# 47
# 94
# list index out of range

# %%
try:
  a=int(input())
  b=int(input())
except Exception as e:
  print(e)
print('ifbdihf')
# Out:
# ygyu
# invalid literal for int() with base 10: 'ygyu'
# ifbdihf

# %%
try:
  d={'key1':'ihbfs','key2':[1,26,6,8,1],'key3':(4,'kjhf',64)}
  d['key4']=int(input())
except Exception as e:
  print(e)
# Out:
# ihi
# invalid literal for int() with base 10: 'ihi'

# %% [markdown]
# *   Exception is a super class
# *   ValueError,divisionbyzero type of errors are subclass

# %%
try:
  d={'key1':'ihbfs','key2':[1,26,6,8,1],'key3':(4,'kjhf',64)}
  d['key4']=int(input())
except ValueError as e:
  print(e)
# Out:
# iuhyug
# invalid literal for int() with base 10: 'iuhyug'

# %%
try:
  d={'key1':'ihbfs','key2':[1,26,6,8,1],'key3':(4,'kjhf',64)}
  d['key4']=int(input())
  f=open('test2.txt','r')
except ValueError as e:
  print(e)
# Out:
# 658798
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-e467fada0915> in <module>
#       2   d={'key1':'ihbfs','key2':[1,26,6,8,1],'key3':(4,'kjhf',64)}
#       3   d['key4']=int(input())
# ----> 4   f=open('test2.txt','r')
#       5 except ValueError as e:
#       6   print(e)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test2.txt'

# %% [markdown]
# *  This is not a ValueError so it was not able to handle
# *   We can write multiple subclasses

# %%
try:
  d={'key1':'ihbfs','key2':[1,26,6,8,1],'key3':(4,'kjhf',64)}
  d['key4']=int(input())
  f=open('test2.txt','r')
except ValueError as e:
  print(e)
except FileNotFoundError as bharg:
  print(bharg)
# Out:
# 6848
# [Errno 2] No such file or directory: 'test2.txt'

# %%
try:
  d={'key1':'ihbfs','key2':[1,26,6,8,1],'key3':(4,'kjhf',64)}
  d['key4']=int(input())
  f=open('test2.txt','r')
except Exception as e1:
  print('this is exception class',e1)
except ValueError as e:
  print(e)
except FileNotFoundError as bharg:
  print(bharg)
# Out:
# hfh
# this is exception class invalid literal for int() with base 10: 'hfh'

# %%
try:
  d={'key1':'ihbfs','key2':[1,26,6,8,1],'key3':(4,'kjhf',64)}
  d['key4']=int(input())
  f=open('test2.txt','r')

except ValueError as e:
  print(e)
except FileNotFoundError as bharg:
  print(bharg)
except Exception as e1:
  print('this is exception class',e1)
# Out:
# heytr
# invalid literal for int() with base 10: 'heytr'

# %%
try:
  f=open('test1.txt','w')
  f.write('fjibfef ijdbifbha jnbiudasgs')
except Exception as bharg:
  print('handling error',e)
else:
  print('this will run when try block run sucessfully')
  f.close()
# Out:
# this will run when try block run sucessfully

# %%
try:
  f=open('test2.txt','r')
  f.write('josdif ijbfisbc jnbfisdb ')
except Exception as e:
  print('handling',e)
else:
  print('on sucessful run of try block')
finally:
  print('do for sure')
# Out:
# handling [Errno 2] No such file or directory: 'test2.txt'
# do for sure

# %%
try:
  f=open('test2.txt','r')
  f.write('josdif ijbfisbc jnbfisdb ')
except Exception as e:
  print('handling',e)
else:
  print('on sucessful run of try block')
finally:
  print('do for sure')
  try:
    f=open('ijhfsnkj.txt','r')
  except:
    print('handle')
  finally:
    print('ending')
# Out:
# handling [Errno 2] No such file or directory: 'test2.txt'
# do for sure
# handle
# ending

# %%
def askint():
  a=int(input())
  return a

# %%
askint()
# Out:
# 5
# 5

# %%
askint()
# Out:
# vsdvsd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-cc291aa76c10> in <module>
# ----> 1 askint()
#
# <ipython-input-48-b0c66d26ebdd> in askint()
#       1 def askint():
# ----> 2   a=int(input())
#       3   return a
#
# ValueError: invalid literal for int() with base 10: 'vsdvsd'

# %%
def askint():
  try:
    a=int(input())
    return a
  except Exception as e:
    print('this is an input error',e)

# %%
askint()
# Out:
# fjiurwj
# enetr an inetrger value
# dfgrg
# enetr an inetrger value
# er
# enetr an inetrger value
# ererg
# enetr an inetrger value
# 5484

# %%
def askint():
  try:
    a=int(input())
    print('integer',a)
    return a
  except:
    print('enter an inetrger value')
    askint()

# %%
askint()
# Out:
# kjsdhfuisd][fioh
# enter an inetrger value
# giuhfe
# enter an inetrger value
# kjfhf
# enter an inetrger value
# 49
# integer 49

# %%
def test(a):
  if a<0:
    raise Exception(a)
  return a

# %%
test(-4)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-66-d2bb95962d49> in <module>
# ----> 1 test(-4)
#
# <ipython-input-65-c1ebd44f377a> in test(a)
#       1 def test(a):
#       2   if a<0:
# ----> 3     raise Exception(a)
#       4   return a
#
# Exception: -4

# %%
def test(a):
  if a<0:
    raise Exception('you have entered a negative value')
  return a

# %%
test(-4)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-69-d2bb95962d49> in <module>
# ----> 1 test(-4)
#
# <ipython-input-68-b7f33cb0e7d7> in test(a)
#       1 def test(a):
#       2   if a<0:
# ----> 3     raise Exception('you have entered a negative value')
#       4   return a
#
# Exception: you have entered a negative value

# %%
def test(a):
  if a<0:
    raise ZeroDivisionError('you have entered a negative value')
  return a

# %%
test(-4)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-75-d2bb95962d49> in <module>
# ----> 1 test(-4)
#
# <ipython-input-74-184ad28b039d> in test(a)
#       1 def test(a):
#       2   if a<0:
# ----> 3     raise ZeroDivisionError('you have entered a negative value')
#       4   return a
#
# ZeroDivisionError: you have entered a negative value

# %%
try:
  test(int(input()))
except Exception as e:
  print('hadling error is: ',e)
# Out:
# -84
# hadling error is:  you have entered a negative value

# %%
import mydict
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-39e46509dcb4> in <module>
# ----> 1 import mydict
#
# ModuleNotFoundError: No module named 'mydict'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
